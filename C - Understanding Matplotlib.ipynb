# %% [markdown]
# # Understanding Matplotlib
#
# Materials adapted from the RealPython tutorial [Python Plotting with Matplotlib](https://realpython.com/python-matplotlib-guide/)
#
# **Table of Content**
#
# 1. [Setting up matplotlib](#sec1)
# 2. [Creating one plot and changing its style](#sec2)
# 3. [Creating subplots](#sec3)
# 4. [Real-data example: California Housing](#sec4)

# %% [markdown]
# <a id="sec1"></a>
# ## 1. Setting up matplotlib

# %% [markdown]
# **Importing what we need**

# %%
#pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(444) # initializes our random number generator

# %% [markdown]
# **The simplest plot**

# %%
plt.plot([4, 5, 6])

# %% [markdown]
# **The top object: `figure`**

# %%
fig, ax = plt.subplots()
print(type(fig))
# Out:
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# **Use object hierarchy to get a nested element**

# %%
one_tick = fig.axes[0].yaxis.get_major_ticks()[0]
type(one_tick)
# Out:
# matplotlib.axis.YTick

# %% [markdown]
# <a id="sec2"></a>
# ## 2. Creating one plot
#
# Creating and decorating a single plot.

# %%
# Generate data
import numpy as np
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng

# %%
# Generate plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper left')
ax.set_ylabel('Total debt')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1]) # range of values
fig.tight_layout() # clean whitespace

# %% [markdown]
# **Changing the plot style**
#
# The default matplotlib style is not that appealing. It is possible to change the appearance of the entire plot, by setting the style of the image. Each style has its own color scheme, font family and font size, background color, grids, etc. Here are some examples of famous styles:

# %%
# The famous data & statisics website 
plt.style.use('fivethirtyeight')

# %%
# Generate plot
def generateOnePlot():
    fig, ax = plt.subplots(figsize=(5, 3))
    ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
    ax.set_title('Combined debt growth over time')
    ax.legend(loc='upper left')
    ax.set_ylabel('Total debt')
    ax.set_xlim(xmin=yrs[0], xmax=yrs[-1]) # range of values
    fig.tight_layout() # clean whitespace

generateOnePlot()

# %%
# The famouos R library for plotting, ggplot
plt.style.use('ggplot')

# %%
generateOnePlot()

# %% [markdown]
# Matplotlib has many more styles, you can find them as follows:

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'petroff6', 'petroff8', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# **Try out some of the styles below**
#
# Replace the value of "bmh" to any of the values shown above, and rerun the cell.

# %%
plt.style.use('ggplot') 
generateOnePlot()

# %% [markdown]
# <a id="sec3"></a>
# ## 3. Creating subplots

# %%
plt.style.use('ggplot') 


# Generate the data
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)
data = np.column_stack((x, y))

# Create figure and axes
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,
                               figsize=(8, 4))

# Create the first subplot as a scatterplot
ax1.scatter(x=x, y=y, marker='o', c='r', edgecolor='b')
ax1.set_title('Scatter: $x$ versus $y$')
ax1.set_xlabel('$x$') # Use TeX style, by enclosing value in the dollar signs to italize it
ax1.set_ylabel('$y$')

# Create the second subplot as a scatterplot
ax2.hist(data, bins=np.arange(data.min(), data.max()),
         label=('x', 'y'))
ax2.legend(loc=(0.65, 0.8))
ax2.set_title('Frequencies of $x$ and $y$')
ax2.yaxis.tick_right()

# %% [markdown]
# Let's create a 2x2 grid of subplots:

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(7, 7))

# %% [markdown]
# What is the value of ax at the moment?

# %%
ax
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
type(ax)
# Out:
# numpy.ndarray

# %% [markdown]
# It's a numpy array. To access each axes we would have to do double indexing, such as:

# %%
ax[1][1]
# Out:
# <Axes: >

# %% [markdown]
# But, we can also **flatten** the array, so that it becomes a list, which is easier to index:

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(7, 7))
ax1, ax2, ax3, ax4 = ax.flatten()  # flatten a 2d NumPy array to 1d

# %% [markdown]
# <a id="sec4"></a>
# ## 4. Read data example: California Housing

# %%
# from io import BytesIO
# import tarfile
# from urllib.request import urlopen

# url = 'http://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.tgz'
# b = BytesIO(urlopen(url).read())
# fpath = 'CaliforniaHousing/cal_housing.data'

# with tarfile.open(mode='r', fileobj=b) as archive:
#     housing = np.loadtxt(archive.extractfile(fpath), delimiter=',')


# #unable to do bc link doesn't work!!

# %% [markdown]
# How big is the array housing?

# %%
#housing.shape

# %%
#housing[0]

# %% [markdown]
# Let's create a dataframe, just to see the data:

# %%
import pandas as pd

# %%
#import another dataset
housing = pd.read_csv("C://Users//iwuba//Downloads//Wellesley_Year_3//STAT318//datasets//nashville.txt")

# %%
df = pd.DataFrame(housing)
df.head()
# Out:
#    Time
# 0   251
# 1   263
# 2   265
# 3   240
# 4   268

# %% [markdown]
# Get the response variable (or the dependent variable), which corresponds to the "area's average home value".
# This is the last column:

# %%
y = housing[:, -1] #throws error bc only one column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), -1)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 y = housing[:, -1]
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3824, in Index.get_loc(self, key)
#    3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
# -> 3824     self._check_indexing_error(key)
#    3825     raise
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6072, in Index._check_indexing_error(self, key)
#    6068 def _check_indexing_error(self, key):
#    6069     if not is_scalar(key):
#    6070         # if key is not a scalar, directly raise an error (the code below
#    6071         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6072         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), -1)

# %% [markdown]
# Let's name two other variables:
#
# `pop` - area's population
# `age` - the average house age

# %%
pop, age = housing[:, [4, 7]].T # transpose from vertical column to horizontal row; error bc my dataset has only 1 column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), [4, 7])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pop, age = housing[:, [4, 7]].T # transpose from vertical column to horizontal row
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3824, in Index.get_loc(self, key)
#    3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
# -> 3824     self._check_indexing_error(key)
#    3825     raise
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6072, in Index._check_indexing_error(self, key)
#    6068 def _check_indexing_error(self, key):
#    6069     if not is_scalar(key):
#    6070         # if key is not a scalar, directly raise an error (the code below
#    6071         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6072         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), [4, 7])

# %% [markdown]
# **Helper function for the inplot title**

# %%
def add_titlebox(ax, text):
    ax.text(.55, .8, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=12.5)
    return ax

# %% [markdown]
# **Create a subgrid and plot the data**

# %%
import matplotlib.pyplot as plt

# %%
# Create the grid
gridsize = (3, 2)
fig = plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))


# Plot data in each axes of the grid
ax1.set_title('Home value as a function of home age & area population',
              fontsize=14)
sctr = ax1.scatter(x=age, y=pop, c=y, cmap='RdYlGn')
plt.colorbar(sctr, ax=ax1, format='$%d')
ax1.set_yscale('log')
ax2.hist(age, bins='auto')
ax3.hist(pop, bins='auto', log=True)

add_titlebox(ax2, 'Histogram: home age')
add_titlebox(ax3, 'Histogram: area population (log scl.)')

plt.savefig("california-housing.png") # make sure to save it
plt.show()

#throws error bc data isn't the same set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       9 # Plot data in each axes of the grid
#      10 ax1.set_title('Home value as a function of home age & area population',
#      11               fontsize=14)
# ---> 12 sctr = ax1.scatter(x=age, y=pop, c=y, cmap='RdYlGn')
#      13 plt.colorbar(sctr, ax=ax1, format='$%d')
#      14 ax1.set_yscale('log')
#
# NameError: name 'age' is not defined
